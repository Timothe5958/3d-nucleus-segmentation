# %% [markdown]
# # Reader

# %% [markdown]
# The purpose of this notebook is to show how to use the czi file reader.

# %%
import matplotlib.pyplot as plt

from nucleus_segmentation import CziReader

# %% [markdown]
# The import of the data can be done only using the file path.

# %%
observation = CziReader('../data/data_test.czi')

# %% [markdown]
# We can then display the "slice" with a designated number this way (here a slice means a given z):

# %%
plt.imshow(observation.get_slice(152), cmap='gray')
